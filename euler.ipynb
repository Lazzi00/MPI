# %%
import math

# Constantes
pi = 3.14
w0 = 1
f = 0
aL = 0.
h = 0.01
w = 1

    

# Fonction pour calculer l'accélération angulaire
def g(t, theta, v):
    return -w0**2 * math.sin(theta) - aL * v + f * math.cos(w * t)

# Fonction pour retourner la vitesse
def f_func(t, theta, v):
    return v

# Initialisation des variables
t = 0.0
theta = pi / 5
v = 0
T = 2 * pi / w0

# Ouverture du fichier pour l'écriture

# %%
with open("e.csv", "w") as fp:
    
    print(f"{t} {theta} {v}")
    fp.write("t,theta,v\n")

    # Boucle d'itération
    t = h
    while t <= 3 * T:
        theta = theta + h * f_func(t, theta, v)
        v = v + h * g(t, theta, v)
        fp.write(f"{t},{theta},{v}\n")
        t += h
# Out:
# 0.0 0.628 0

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
A = pd.read_csv("e.csv")

# %%
X=A["t"]
Y=A["theta"]
Z=A["v"]

# %%
X
# Out:
# 0        0.01
# 1        0.02
# 2        0.03
# 3        0.04
# 4        0.05
#         ...
# 1878    18.79
# 1879    18.80
# 1880    18.81
# 1881    18.82
# 1882    18.83
# Name: t, Length: 1883, dtype: float64

# %%
plt.plot(X,Y)

# %%
plt.plot(X,Z)

# %%
plt.plot(Y,Z)
